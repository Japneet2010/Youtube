# %%
import matplotlib.pyplot as plt
import numpy as np
xpos = np.array([0,1,6])
ypos = np.array([0,5,3])
plt.plot(xpos, ypos)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
students = np.array(["Student1", "Student2", "Student3","Student4","Student5"])
marks = np.array([66,96,75,55,98])
plt.title("Marksheet", fontdict={"fontname":"Comic Sans MS", "fontsize":30})
plt.grid()
plt.plot(students, marks)
plt.show()
